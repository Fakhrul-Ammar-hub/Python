# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Document\Data Analyst Bootcamp\Python\csv files\companies.csv')
df
# Out:
#    Rank  Forbes 2000 rank                          Name  Headquarters  \
# 0     1               364                       Maybank  Kuala Lumpur
# 1     2               679               Tenaga Nasional  Kuala Lumpur
# 2     3               694            Public Bank Berhad  Kuala Lumpur
# 3     4              1175           CIMB Group Holdings  Kuala Lumpur
# 4     5              1400                      RHB Bank  Kuala Lumpur
# 5     6              1404    Hong Leong Financial Group  Kuala Lumpur
# 6     7              1448  Top Glove Corporation Berhad  Kuala Lumpur
# 7     8              1958            Petronas Chemicals  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# ...

# %%
df = pd.read_csv('D:\Document\Data Analyst Bootcamp\Python\csv files\companies.csv', index_col="Name")
df
# Out:
#                               Rank  Forbes 2000 rank  Headquarters  \
# Name
# Maybank                          1               364  Kuala Lumpur
# Tenaga Nasional                  2               679  Kuala Lumpur
# Public Bank Berhad               3               694  Kuala Lumpur
# CIMB Group Holdings              4              1175  Kuala Lumpur
# RHB Bank                         5              1400  Kuala Lumpur
# Hong Leong Financial Group       6              1404  Kuala Lumpur
# Top Glove Corporation Berhad     7              1448  Kuala Lumpur
# Petronas Chemicals               8              1958  Kuala Lumpur
#
#                               Revenue(billions US$)  Profit(billions US$)  \
# Name
# Maybank                                        10.5                   1.5
# Tenaga Nasional                                10.5                   0.9
# Public Bank Berhad                              4.5                   1.2
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                            Name  Rank  Forbes 2000 rank  Headquarters  \
# 0                       Maybank     1               364  Kuala Lumpur
# 1               Tenaga Nasional     2               679  Kuala Lumpur
# 2            Public Bank Berhad     3               694  Kuala Lumpur
# 3           CIMB Group Holdings     4              1175  Kuala Lumpur
# 4                      RHB Bank     5              1400  Kuala Lumpur
# 5    Hong Leong Financial Group     6              1404  Kuala Lumpur
# 6  Top Glove Corporation Berhad     7              1448  Kuala Lumpur
# 7            Petronas Chemicals     8              1958  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# ...

# %%
df.set_index('Name',inplace = True)
df
# Out:
#                               Rank  Forbes 2000 rank  Headquarters  \
# Name
# Maybank                          1               364  Kuala Lumpur
# Tenaga Nasional                  2               679  Kuala Lumpur
# Public Bank Berhad               3               694  Kuala Lumpur
# CIMB Group Holdings              4              1175  Kuala Lumpur
# RHB Bank                         5              1400  Kuala Lumpur
# Hong Leong Financial Group       6              1404  Kuala Lumpur
# Top Glove Corporation Berhad     7              1448  Kuala Lumpur
# Petronas Chemicals               8              1958  Kuala Lumpur
#
#                               Revenue(billions US$)  Profit(billions US$)  \
# Name
# Maybank                                        10.5                   1.5
# Tenaga Nasional                                10.5                   0.9
# Public Bank Berhad                              4.5                   1.2
# ...

# %%
df.loc['Petronas Chemicals']
# Out:
# Rank                                8
# Forbes 2000 rank                 1958
# Headquarters             Kuala Lumpur
# Revenue(billions US$)             3.4
# Profit(billions US$)              0.4
# Assets(billions US$)             10.3
# Value(billions US$)              15.4
# Industry                  Oil and Gas
# Name: Petronas Chemicals, dtype: object

# %%
df.iloc[7]
# Out:
# Rank                                8
# Forbes 2000 rank                 1958
# Headquarters             Kuala Lumpur
# Revenue(billions US$)             3.4
# Profit(billions US$)              0.4
# Assets(billions US$)             10.3
# Value(billions US$)              15.4
# Industry                  Oil and Gas
# Name: Petronas Chemicals, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                            Name  Rank  Forbes 2000 rank  Headquarters  \
# 0                       Maybank     1               364  Kuala Lumpur
# 1               Tenaga Nasional     2               679  Kuala Lumpur
# 2            Public Bank Berhad     3               694  Kuala Lumpur
# 3           CIMB Group Holdings     4              1175  Kuala Lumpur
# 4                      RHB Bank     5              1400  Kuala Lumpur
# 5    Hong Leong Financial Group     6              1404  Kuala Lumpur
# 6  Top Glove Corporation Berhad     7              1448  Kuala Lumpur
# 7            Petronas Chemicals     8              1958  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# ...

# %%
df.set_index(['Rank','Name'],inplace = True)
df
# Out:
#                                    Forbes 2000 rank  Headquarters  \
# Rank Name
# 1    Maybank                                    364  Kuala Lumpur
# 2    Tenaga Nasional                            679  Kuala Lumpur
# 3    Public Bank Berhad                         694  Kuala Lumpur
# 4    CIMB Group Holdings                       1175  Kuala Lumpur
# 5    RHB Bank                                  1400  Kuala Lumpur
# 6    Hong Leong Financial Group                1404  Kuala Lumpur
# 7    Top Glove Corporation Berhad              1448  Kuala Lumpur
# 8    Petronas Chemicals                        1958  Kuala Lumpur
#
#                                    Revenue(billions US$)  \
# Rank Name
# 1    Maybank                                        10.5
# 2    Tenaga Nasional                                10.5
# 3    Public Bank Berhad                              4.5
# 4    CIMB Group Holdings                             6.1
# 5    RHB Bank                                        2.6
# ...

# %%
df.sort_index()

#pd.set_option('display.max.rows',xxx)
# Out:
#                                    Forbes 2000 rank  Headquarters  \
# Rank Name
# 1    Maybank                                    364  Kuala Lumpur
# 2    Tenaga Nasional                            679  Kuala Lumpur
# 3    Public Bank Berhad                         694  Kuala Lumpur
# 4    CIMB Group Holdings                       1175  Kuala Lumpur
# 5    RHB Bank                                  1400  Kuala Lumpur
# 6    Hong Leong Financial Group                1404  Kuala Lumpur
# 7    Top Glove Corporation Berhad              1448  Kuala Lumpur
# 8    Petronas Chemicals                        1958  Kuala Lumpur
#
#                                    Revenue(billions US$)  \
# Rank Name
# 1    Maybank                                        10.5
# 2    Tenaga Nasional                                10.5
# 3    Public Bank Berhad                              4.5
# 4    CIMB Group Holdings                             6.1
# 5    RHB Bank                                        2.6
# ...

# %%
df.loc[1,'Maybank']
# Out:
# Forbes 2000 rank                  364
# Headquarters             Kuala Lumpur
# Revenue(billions US$)            10.5
# Profit(billions US$)              1.5
# Assets(billions US$)              213
# Value(billions US$)              22.9
# Industry                      Banking
# Name: (1, Maybank), dtype: object
