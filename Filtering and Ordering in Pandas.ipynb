# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Document\Data Analyst Bootcamp\Python\csv files\companies.csv')

# %%
df
# Out:
#    Rank  Forbes 2000 rank                          Name  Headquarters  \
# 0     1               364                       Maybank  Kuala Lumpur
# 1     2               679               Tenaga Nasional  Kuala Lumpur
# 2     3               694            Public Bank Berhad  Kuala Lumpur
# 3     4              1175           CIMB Group Holdings  Kuala Lumpur
# 4     5              1400                      RHB Bank  Kuala Lumpur
# 5     6              1404    Hong Leong Financial Group  Kuala Lumpur
# 6     7              1448  Top Glove Corporation Berhad  Kuala Lumpur
# 7     8              1958            Petronas Chemicals  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# ...

# %%
df[df['Rank']<=5]
# Out:
#    Rank  Forbes 2000 rank                 Name  Headquarters  \
# 0     1               364              Maybank  Kuala Lumpur
# 1     2               679      Tenaga Nasional  Kuala Lumpur
# 2     3               694   Public Bank Berhad  Kuala Lumpur
# 3     4              1175  CIMB Group Holdings  Kuala Lumpur
# 4     5              1400             RHB Bank  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# 3                    6.1                   0.3                 149.7
# 4                    2.6                   0.5                  67.4
#
#    Value(billions US$)   Industry
# 0                 22.9    Banking
# 1                 13.9  Utilities
# 2                 19.8    Banking
# 3                 10.3    Finance
# ...

# %%
specific_name = ['Maybank', 'RHB Bank']

df[df['Name'].isin(specific_name)]
# Out:
#    Rank  Forbes 2000 rank      Name  Headquarters  Revenue(billions US$)  \
# 0     1               364   Maybank  Kuala Lumpur                   10.5
# 4     5              1400  RHB Bank  Kuala Lumpur                    2.6
#
#    Profit(billions US$)  Assets(billions US$)  Value(billions US$) Industry
# 0                   1.5                 213.0                 22.9  Banking
# 4                   0.5                  67.4                  5.2  Banking

# %%
df[df['Name'].str.contains('Berhad')]
# Out:
#    Rank  Forbes 2000 rank                          Name  Headquarters  \
# 2     3               694            Public Bank Berhad  Kuala Lumpur
# 6     7              1448  Top Glove Corporation Berhad  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 2                    4.5                   1.2                 112.2
# 6                    3.6                   1.6                   3.1
#
#    Value(billions US$) Industry
# 2                 19.8  Banking
# 6                 10.8   Rubber

# %%
df2 = df.set_index('Name')
df
# Out:
#    Rank  Forbes 2000 rank                          Name  Headquarters  \
# 0     1               364                       Maybank  Kuala Lumpur
# 1     2               679               Tenaga Nasional  Kuala Lumpur
# 2     3               694            Public Bank Berhad  Kuala Lumpur
# 3     4              1175           CIMB Group Holdings  Kuala Lumpur
# 4     5              1400                      RHB Bank  Kuala Lumpur
# 5     6              1404    Hong Leong Financial Group  Kuala Lumpur
# 6     7              1448  Top Glove Corporation Berhad  Kuala Lumpur
# 7     8              1958            Petronas Chemicals  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# ...

# %%
df2.filter(items = ['Rank','Industry'], axis = 1)
# Out:
#                               Rank      Industry
# Name
# Maybank                          1       Banking
# Tenaga Nasional                  2     Utilities
# Public Bank Berhad               3       Banking
# CIMB Group Holdings              4       Finance
# RHB Bank                         5       Banking
# Hong Leong Financial Group       6  Conglomerate
# Top Glove Corporation Berhad     7        Rubber
# Petronas Chemicals               8   Oil and Gas

# %%
df2.filter(items = ['Maybank'], axis = 0)
# Out:
#          Rank  Forbes 2000 rank  Headquarters  Revenue(billions US$)  \
# Name
# Maybank     1               364  Kuala Lumpur                   10.5
#
#          Profit(billions US$)  Assets(billions US$)  Value(billions US$)  \
# Name
# Maybank                   1.5                 213.0                 22.9
#
#         Industry
# Name
# Maybank  Banking

# %%
df2.filter(like = 'Berhad', axis = 0)
# Out:
#                               Rank  Forbes 2000 rank  Headquarters  \
# Name
# Public Bank Berhad               3               694  Kuala Lumpur
# Top Glove Corporation Berhad     7              1448  Kuala Lumpur
#
#                               Revenue(billions US$)  Profit(billions US$)  \
# Name
# Public Bank Berhad                              4.5                   1.2
# Top Glove Corporation Berhad                    3.6                   1.6
#
#                               Assets(billions US$)  Value(billions US$)  \
# Name
# Public Bank Berhad                           112.2                 19.8
# Top Glove Corporation Berhad                   3.1                 10.8
#
#                              Industry
# Name
# Public Bank Berhad            Banking
# Top Glove Corporation Berhad   Rubber

# %%
df2.loc['Maybank']
# Out:
# Rank                                1
# Forbes 2000 rank                  364
# Headquarters             Kuala Lumpur
# Revenue(billions US$)            10.5
# Profit(billions US$)              1.5
# Assets(billions US$)              213
# Value(billions US$)              22.9
# Industry                      Banking
# Name: Maybank, dtype: object

# %%
df2.iloc[4]
# Out:
# Rank                                5
# Forbes 2000 rank                 1400
# Headquarters             Kuala Lumpur
# Revenue(billions US$)             2.6
# Profit(billions US$)              0.5
# Assets(billions US$)             67.4
# Value(billions US$)               5.2
# Industry                      Banking
# Name: RHB Bank, dtype: object

# %%
df
# Out:
#    Rank  Forbes 2000 rank                          Name  Headquarters  \
# 0     1               364                       Maybank  Kuala Lumpur
# 1     2               679               Tenaga Nasional  Kuala Lumpur
# 2     3               694            Public Bank Berhad  Kuala Lumpur
# 3     4              1175           CIMB Group Holdings  Kuala Lumpur
# 4     5              1400                      RHB Bank  Kuala Lumpur
# 5     6              1404    Hong Leong Financial Group  Kuala Lumpur
# 6     7              1448  Top Glove Corporation Berhad  Kuala Lumpur
# 7     8              1958            Petronas Chemicals  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 0                   10.5                   1.5                 213.0
# 1                   10.5                   0.9                  45.1
# 2                    4.5                   1.2                 112.2
# ...

# %%
#ordering

# %%
df[df['Rank']<=5].sort_values(by=['Rank','Name'],ascending=False)
# Out:
#    Rank  Forbes 2000 rank                 Name  Headquarters  \
# 4     5              1400             RHB Bank  Kuala Lumpur
# 3     4              1175  CIMB Group Holdings  Kuala Lumpur
# 2     3               694   Public Bank Berhad  Kuala Lumpur
# 1     2               679      Tenaga Nasional  Kuala Lumpur
# 0     1               364              Maybank  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 4                    2.6                   0.5                  67.4
# 3                    6.1                   0.3                 149.7
# 2                    4.5                   1.2                 112.2
# 1                   10.5                   0.9                  45.1
# 0                   10.5                   1.5                 213.0
#
#    Value(billions US$)   Industry
# 4                  5.2    Banking
# 3                 10.3    Finance
# 2                 19.8    Banking
# 1                 13.9  Utilities
# ...

# %%
df[df['Rank']<=5].sort_values(by=['Name','Rank'],ascending=False)
# Out:
#    Rank  Forbes 2000 rank                 Name  Headquarters  \
# 1     2               679      Tenaga Nasional  Kuala Lumpur
# 4     5              1400             RHB Bank  Kuala Lumpur
# 2     3               694   Public Bank Berhad  Kuala Lumpur
# 0     1               364              Maybank  Kuala Lumpur
# 3     4              1175  CIMB Group Holdings  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 1                   10.5                   0.9                  45.1
# 4                    2.6                   0.5                  67.4
# 2                    4.5                   1.2                 112.2
# 0                   10.5                   1.5                 213.0
# 3                    6.1                   0.3                 149.7
#
#    Value(billions US$)   Industry
# 1                 13.9  Utilities
# 4                  5.2    Banking
# 2                 19.8    Banking
# 0                 22.9    Banking
# ...

# %%
df[df['Rank']<=5].sort_values(by=['Name','Rank'],ascending=[False,True])
# Out:
#    Rank  Forbes 2000 rank                 Name  Headquarters  \
# 1     2               679      Tenaga Nasional  Kuala Lumpur
# 4     5              1400             RHB Bank  Kuala Lumpur
# 2     3               694   Public Bank Berhad  Kuala Lumpur
# 0     1               364              Maybank  Kuala Lumpur
# 3     4              1175  CIMB Group Holdings  Kuala Lumpur
#
#    Revenue(billions US$)  Profit(billions US$)  Assets(billions US$)  \
# 1                   10.5                   0.9                  45.1
# 4                    2.6                   0.5                  67.4
# 2                    4.5                   1.2                 112.2
# 0                   10.5                   1.5                 213.0
# 3                    6.1                   0.3                 149.7
#
#    Value(billions US$)   Industry
# 1                 13.9  Utilities
# 4                  5.2    Banking
# 2                 19.8    Banking
# 0                 22.9    Banking
# ...
